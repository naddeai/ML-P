# %% [markdown]
# # SHAP (SHapley Additive exPlanations)

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_base = pd.read_csv('../../../data/house-price.csv', index_col=0)
df_base
# Out:
#                        PRICE  BEDROOMS  BATHROOMS  GARAGE  FLOOR_AREA  \
# ADDRESS
# 1 Datchet Turn        270000         3          2     2.0         109
# 1 McKenzie Corner     470000         4          2     2.0         279
# ...                      ...       ...        ...     ...         ...
# 93 Centennial Avenue  350000         4          2     2.0         177
# 98 Centennial Avenue  441000         4          2     2.0         195
#
#                       BUILD_YEAR
# ADDRESS
# 1 Datchet Turn            2011.0
# 1 McKenzie Corner         2005.0
# ...                          ...
# 93 Centennial Avenue      2005.0
# 98 Centennial Avenue      2004.0
#
# [204 rows x 6 columns]

# %% [markdown]
# ## Feature selection

# %%
y = df_base['PRICE']
X = df_base.drop(columns='PRICE')

# %% [markdown]
# ## Train model

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.9746449876358452

# %%
pd.DataFrame({
    'y_true': y,
    'y_pred': model.predict(X)
})
# Out:
#                       y_true    y_pred
# ADDRESS
# 1 Datchet Turn        270000  270000.0
# 1 McKenzie Corner     470000  470000.0
# ...                      ...       ...
# 93 Centennial Avenue  350000  350000.0
# 98 Centennial Avenue  441000  441000.0
#
# [204 rows x 2 columns]

# %%
df_base
# Out:
#                        PRICE  BEDROOMS  BATHROOMS  GARAGE  FLOOR_AREA  \
# ADDRESS
# 1 Datchet Turn        270000         3          2     2.0         109
# 1 McKenzie Corner     470000         4          2     2.0         279
# ...                      ...       ...        ...     ...         ...
# 93 Centennial Avenue  350000         4          2     2.0         177
# 98 Centennial Avenue  441000         4          2     2.0         195
#
#                       BUILD_YEAR
# ADDRESS
# 1 Datchet Turn            2011.0
# 1 McKenzie Corner         2005.0
# ...                          ...
# 93 Centennial Avenue      2005.0
# 98 Centennial Avenue      2004.0
#
# [204 rows x 6 columns]

# %% [markdown]
# ## SHAP: Model explainability
#
# How the values of the features affect the prediction of the model.

# %% [markdown]
# ### Explainer

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

# %% [markdown]
# ### Explain individual prediction

# %%
shap.initjs()
idx = 0
sample = X.iloc[idx].copy()
shap.force_plot(explainer.expected_value, shap_values[idx], sample)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i5BBTE46MBHLAMFFAOVZD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 386672.54901960783, "outValue": 269999.9999999999, "link": "identity", "featureNames": ["BEDROOMS", "BATHROOMS", "GARAGE", "FLOOR_AREA", "BUILD_YEAR"], "features": {"0": {"effect": -26383.547633974515, "value": 3.0}, "2": {"effect": 3187.4806725809945, "value": 2.0}, "3": {"effect": -74519.72075589825, "value": 109.0}, "4": {"effect": -18956.761302316154, "value": 2011.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i5BBTE46MBHLAMFFAOVZD')
#   );
# </script>

# %% [markdown]
# ### Full dataset
#
# #### Decision plot

# %%
shap.decision_plot(explainer.expected_value, shap_values, X)

# %% [markdown]
# #### Force plot

# %%
shap.force_plot(explainer.expected_value, shap_values, X)
# Out:
# <div id='iY1E5D96Y4STJ4I822T5U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 386672.54901960783, "link": "identity", "featureNames": ["BEDROOMS", "BATHROOMS", "GARAGE", "FLOOR_AREA", "BUILD_YEAR"], "explanations": [{"outValue": 269999.9999999999, "simIndex": 14.0, "features": {"0": {"effect": -26383.547633974515, "value": 3.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 3187.4806725809945, "value": 2.0}, "3": {"effect": -74519.72075589825, "value": 109.0}, "4": {"effect": -18956.761302316154, "value": 2011.0}}}, {"outValue": 470000.00000000023, "simIndex": 202.0, "features": {"0": {"effect": 3717.6512966436217, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1209.3994385330384, "value": 2.0}, "3": {"effect": 90314.71135971021, "value": 279.0}, "4": {"effect": -11914.311114494474, "value": 2005.0}}}, {"outValue": 445000.00000000023, "simIndex": 154.0, "features": {"0": {"effect": 14260.143132734469, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 2350.7149309035944, "value": 2.0}, "3": {"effect": 18414.088393304628, "value": 200.0}, "4": {"effect": 23302.504523449676, "value": 2004.0}}}, {"outValue": 410000.0000000001, "simIndex": 67.0, "features": {"0": {"effect": 11203.685292741733, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1589.341004812998, "value": 2.0}, "3": {"effect": -11883.596802458735, "value": 148.0}, "4": {"effect": 22418.021485296264, "value": 2005.0}}}, {"outValue": 245000.00000000006, "simIndex": 20.0, "features": {"0": {"effect": -30129.87426997872, "value": 3.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 3489.6296881543076, "value": 1.0}, "3": {"effect": -93840.62017204316, "value": 105.0}, "4": {"effect": -21191.68426574019, "value": 2012.0}}}, {"outValue": 393999.9999999998, "simIndex": 132.0, "features": {"0": {"effect": 3921.5505508811493, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -165.4713688988697, "value": 2.0}, "3": {"effect": 46.27382594183785, "value": 223.0}, "4": {"effect": 3525.0979724678623, "value": 2006.0}}}, {"outValue": 385000.00000000006, "simIndex": 98.0, "features": {"0": {"effect": 9275.1994512461, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -1170.7533758012307, "value": 2.0}, "3": {"effect": -16579.92893968935, "value": 146.0}, "4": {"effect": 6802.933844636714, "value": 2007.0}}}, {"outValue": 410000.0, "simIndex": 143.0, "features": {"0": {"effect": 3974.769245766509, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1399.6697245755597, "value": 2.0}, "3": {"effect": 25482.529437614263, "value": 183.0}, "4": {"effect": -7529.517427564153, "value": 2006.0}}}, {"outValue": 390000.00000000006, "simIndex": 53.0, "features": {"0": {"effect": 18171.694766933873, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -543.4806803444318, "value": 2.0}, "3": {"effect": -29321.703167598527, "value": 153.0}, "4": {"effect": 15020.940061401336, "value": 2003.0}}}, {"outValue": 420000.0, "simIndex": 155.0, "features": {"0": {"effect": 5564.96699131437, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1202.496910299137, "value": 2.0}, "3": {"effect": 19372.302927901343, "value": 190.0}, "4": {"effect": 7187.6841508772895, "value": 2002.0}}}, {"outValue": 160000.00000000003, "simIndex": 29.0, "features": {"0": {"effect": -49335.08976259553, "value": 3.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -30685.339596925936, "value": 3.0}, "3": {"effect": -129711.73263357104, "value": 111.0}, "4": {"effect": -16940.387026515305, "value": 2011.0}}}, {"outValue": 334999.9999999999, "simIndex": 137.0, "features": {"0": {"effect": 5580.21279297705, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -1235.0668197051361, "value": 2.0}, "3": {"effect": -24758.703195195903, "value": 200.0}, "4": {"effect": -31258.991797683968, "value": 2005.0}}}, {"outValue": 382000.0000000001, "simIndex": 97.0, ...

# %% [markdown]
# #### Summary plot

# %%
shap.summary_plot(shap_values, X, plot_type='bar')

# %% [markdown]
# ## Export artifacts
#
# ### SHAP explainer

# %%
import pickle

with open('../artifacts/explainer.pkl', 'wb') as f:
    pickle.dump(explainer, f)

# %% [markdown]
# ### Model

# %%
import pickle

with open('../artifacts/model.pkl', 'wb') as f:
    pickle.dump(model, f)
